# %%
import datetime
import matplotlib as mpl
import backtrader as bt
# %matplotlib inline

import pandas_datareader as pdr

import yfinance as yf
yf.pdr_override()

nvda_df = pdr.DataReader('NVDA', start='2014-01-01', end='2020-05-01', data_source='yahoo')

from bt_strategy import close_vs_sma_strategy

cerebro = close_vs_sma_strategy()
cerebro.broker.setcash(100000.0)

data = bt.feeds.PandasData(dataname=nvda_df)
cerebro.adddata(data)

cerebro.run()

mpl.rc("figure", figsize=(12, 10))
cerebro.plot(iplot=False);

# %%
import datetime
import matplotlib as mpl
import backtrader as bt
# %matplotlib inline

import pandas_datareader as pdr

import yfinance as yf
yf.pdr_override()

nvda_df = pdr.DataReader('NVDA', start='2014-01-01', end='2020-05-01', data_source='yahoo')

from bt_strategy import close_vs_sma_nodrop_strategy

cerebro = close_vs_sma_nodrop_strategy()
cerebro.broker.setcash(100000.0)

data = bt.feeds.PandasData(dataname=nvda_df)
cerebro.adddata(data)

cerebro.run()

mpl.rc("figure", figsize=(12, 10))
cerebro.plot(iplot=False);

# %%
import datetime
import matplotlib as mpl
import backtrader as bt
# %matplotlib inline

import pandas_datareader as pdr

import yfinance as yf
yf.pdr_override()

nvda_df = pdr.DataReader('NVDA', start='2014-01-01', end='2020-05-01', data_source='yahoo')

from bt_strategy import random_strategy

cerebro = random_strategy()
cerebro.broker.setcash(100000.0)

data = bt.feeds.PandasData(dataname=nvda_df)
cerebro.adddata(data)

cerebro.run()

mpl.rc("figure", figsize=(12, 10))
cerebro.plot(iplot=False);

# %%
import datetime
import matplotlib as mpl
import backtrader as bt
# %matplotlib inline

import pandas_datareader as pdr

import yfinance as yf
yf.pdr_override()

nvda_df = pdr.DataReader('NVDA', start='2014-01-01', end='2020-05-01', data_source='yahoo')

from bt_strategy import buy_and_hold_strategy

cerebro = buy_and_hold_strategy()
cerebro.broker.setcash(100000.0)

data = bt.feeds.PandasData(dataname=nvda_df)
cerebro.adddata(data)

cerebro.run()

mpl.rc("figure", figsize=(12, 10))
cerebro.plot(iplot=False);

# %%
import datetime
import matplotlib as mpl
import backtrader as bt
# %matplotlib inline

import pandas_datareader as pdr

import yfinance as yf
yf.pdr_override()

nvda_df = pdr.DataReader('NVDA', start='2014-01-01', end='2020-05-01', data_source='yahoo')

from bt_strategy import mean_reversion_strategy

cerebro = mean_reversion_strategy()
cerebro.broker.setcash(100000.0)

data = bt.feeds.PandasData(dataname=nvda_df)
cerebro.adddata(data)

cerebro.run()

mpl.rc("figure", figsize=(12, 10))
cerebro.plot(iplot=False);

# %%
import datetime
import matplotlib as mpl
import backtrader as bt
# %matplotlib inline

import pandas_datareader as pdr

import yfinance as yf
yf.pdr_override()

nvda_df = pdr.DataReader('NVDA', start='2014-01-01', end='2020-05-01', data_source='yahoo')

from bt_strategy import mean_reversion_nodrop_strategy

cerebro = mean_reversion_nodrop_strategy()
cerebro.broker.setcash(100000.0)

data = bt.feeds.PandasData(dataname=nvda_df)
cerebro.adddata(data)

cerebro.run()

mpl.rc("figure", figsize=(12, 10))
cerebro.plot(iplot=False);

# %%
import datetime
import matplotlib as mpl
import backtrader as bt
# %matplotlib inline

import pandas_datareader as pdr

import yfinance as yf
yf.pdr_override()

nvda_df = pdr.DataReader('NVDA', start='2014-01-01', end='2020-05-01', data_source='yahoo')

from bt_strategy import prev_peak_strategy

cerebro = prev_peak_strategy()
cerebro.broker.setcash(100000.0)

data = bt.feeds.PandasData(dataname=nvda_df)
cerebro.adddata(data)

cerebro.run()

mpl.rc("figure", figsize=(12, 10))
cerebro.plot(iplot=False);

# %%
import datetime
import matplotlib as mpl
import backtrader as bt
# %matplotlib inline

import pandas_datareader as pdr

import yfinance as yf
yf.pdr_override()

nvda_df = pdr.DataReader('NVDA', start='2014-01-01', end='2020-05-01', data_source='yahoo')

from bt_strategy import anti_drop_strategy

cerebro = anti_drop_strategy()
cerebro.broker.setcash(100000.0)

data = bt.feeds.PandasData(dataname=nvda_df)
cerebro.adddata(data)

cerebro.run()

mpl.rc("figure", figsize=(12, 10))
cerebro.plot(iplot=False);
